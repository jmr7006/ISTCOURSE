# %% [markdown]
# <a href="https://colab.research.google.com/github/jmr7006/ISTCOURSE/blob/master/ISTLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pet Shop Diagram Description

# %% [markdown]
# This was my first lab (besides the first) where I have completely worked on my own. The diagram I created isn’t the prettiest, but I believe it portrays how a Pet Shop functions from the pets all the way to the transactions being made. The need for two separate transactions I believe was sufficed by connecting them to the customer, which was then connected to the transaction entity. I tried to show the loyalty program being connected to the customer, linking the customer to both the adoption entity and food entity. That part was definitely confusing to show. Your demonstration in class today definitely helped me show the connection from food to pets more effectively. I also believe my cardinality is spot on. Ultimately, the diagram isn’t the cleanest, but I believe I will continue to build off this one.

# %% [markdown]
# ![Lab2PetShopDiagram.png](data:image/png;base64,...)
